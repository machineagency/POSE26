# %% [markdown]
# # Birdseye Camera
#
# The birdseye camera is an external camera attached to some of the Jubilees. It is calibrated to be able to detect events on the machine and move the a position accordingly (so don't move the camera!) This notebook walks through its basic functionality.

# %%
from science_jubilee.Machine import Machine
from science_jubilee.peripherals.BirdseyeCamera import BirdseyeCamera

machine = Machine(address="192.168.1.2")
birdseye = BirdseyeCamera.from_config('BirdseyeCamera_config.json')
birdseye.attach(machine)

# %%
# We can take pictures and look at them
frame = birdseye.get_frame()
birdseye.show_frame(frame)

# %%
# Then we can move to a pixel!
birdseye.move_to_pixel(1500, 1000)

# %%
# You can also run a 'click to move' demo from your terminal!
# Navigate to your pose26-workshop directory in a terminal
# Activate your virtual environment with source .venv/bin/activate
# then run python3 pose26/birdseye/click_to_move.py
# calibration is set up to run from any z height
# the camera angle may seem misaligned, but if you check on the machine, the tool tip (or z probe) should be decently close!
